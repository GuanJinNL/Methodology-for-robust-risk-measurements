# %% [markdown]
# The problem that we aim to solve is a sampled average optimization problem that has the following form:
# \begin{align}\label{SAA: dual_oce_b1}
# \min_{\substack{\lambda\geq 0\\\theta_1,\theta_2\in \mathbb
#     R}}-\theta_1-\theta_2+\lambda r +\frac{1}{N}\sum^N_{i=1}\lambda \phi^*\left(\frac{\max\{\frac{1}{\alpha}(\theta_2-X_i),0\}+\theta_1}{\lambda}\right),
# \end{align}
# where $r,\alpha>0$ are parameters constants (for example: $r=0.01, \alpha=0.05$) and  $\phi^*$ is the following convex function, twice differentiable, strictly increasing and defined over the entire real line:
#  \begin{align*}
#         \phi^*(x)=\begin{cases}
#            c_1(x+e)e^{0.1\cdot\log^2(x+e)}+c_2x+c_3& x>0\\
#             e^x-1& x\leq 0,
#         \end{cases}
#     \end{align*}
# where $c_1= 5.59, c_2=-6.413, c_3 = -16.793$ are predetermined constants, chosen such that the first and second derivative of $\phi^*$ at $x=0$ are equal from left and right, to ensure twice differentiability of $\phi^*$ also at $x=0$.
#
# It is not really clear if this $\phi^*$ is conic-representable, due to the presence of the $\log^2(x+e)$ term in the exponent which is not convex for $x>0$. However, one can check by second derivative, that $\phi^*$ is strictly convex.
#
# In this problem, $X_i$'s are the i.i.d. samples drawn from a log-normal distribution (with mean zero, variance one). $N$ denotes the number of samples.

# %% [markdown]
# Since the maximum function is non-differentiable, we introduce extra variables to rewrite the above optimization into an optimization problem with differentiable objective functions and constraint functions:
#
# \begin{align}
# \min_{\substack{\lambda\geq 0\\\theta_1,\theta_2\in \mathbb
#     R\\ s_1,\ldots, s_N\geq 0}}&~-\theta_1-\theta_2+\lambda r +\frac{1}{N}\sum^N_{i=1}\lambda \phi^*\left(\frac{s_i+\theta_1}{\lambda}\right)\\
#     \text{subject to}&~\frac{1}{0.05}(\theta_2-X_i)\leq s_i,~i=1,\ldots,N.
# \end{align}
#
# Since the objective functions and the constraint functions here are all twice differentiable, our idea is to use ipopt to solve this optimization problem.

# %% [markdown]
# We import the necessary packages for running the ipopt solver:

# %%
import numpy as np
import cvxpy as cp
import cyipopt    #### the python ipopt wrapper

# %% [markdown]
# To apply ipopt, we need to calculate the gradient and the hessian of the objective and constraint function. To do this, we first start calculating the derivative of our $\phi^*$ function, which is given by:
# \begin{align*}
#         (\phi^*)'(x)=\begin{cases}
#            c_1e^{0.1\cdot\log^2(x+e)}(1+0.2\log(x+e))+c_2& x>0\\
#             e^x& x\leq 0.
#         \end{cases}
#     \end{align*}
# The second derivative $(\phi^*)''$ is given by:
# \begin{align*}
#         (\phi^*)''(x)=\begin{cases}
#            \frac{0.2c_1}{x+e}e^{0.1\cdot\log^2(x+e)}(0.2\log^2(x+e)+\log(x+e)+1)& x>0\\
#             e^x& x\leq 0.
#         \end{cases}
#     \end{align*}

# %% [markdown]
# We implement the function value, derivative and second derivative of $\phi^*$ below:

# %%
def f_explog(x,a,b):   #### default: a=0.1, b=2
    if x > 0 :
        e = np.exp(1)
        ### constants calculations
        
        c1 = 1/(b**2*(a**2+a)*np.exp(a-1))
        c2 = 1 - np.exp(a)*(a*b+1)*c1
        c3 = -np.exp(a+1)*c1
        term = (x+e)*np.exp(a*np.log(x+e)**b) 
        return(c1*term + c2*x + c3)
    else:
        return(np.exp(x)-1)
    
def df_explog(x,a,b):
    if x > 0:
        e = np.exp(1)
        ### constants calculations
        
        c1 = 1/(b**2*(a**2+a)*np.exp(a-1))
        c2 = 1 - np.exp(a)*(a*b+1)*c1
        term = np.exp(a*(np.log(x+e))**b)*(a*b*(np.log(x+e))**(b-1)+1)
        return(c1*term + c2)
    else:
        return(np.exp(x))
    
    
def ddf_explog(x,a,b):
    if x > 0:
        e = np.exp(1)
        c1 = 1/(b**2*(a**2+a)*np.exp(a-1))
        
        term1 = a*b/(x+e)*np.exp(a*np.log(x+e)**b)
        term2 = (b-1)*np.log(x+e)**(b-2) + np.log(x+e)**(b-1) + a*b*np.log(x+e)**(2*b-2)
        return(c1*term1*term2)
    else:
        return(np.exp(x))

# %% [markdown]
# We now generate the log-normal samples $X_i$'s and define the parameters for the optimization problem:

# %%
np.random.seed(10)
X = -(np.random.lognormal(0,1,size= 20))
a = 0.1
b = 2
alpha = 0.05
r = 0.01

# %% [markdown]
# Next, we define the ipopt problem class where we specify the objective, gradient, constraint, jacobian and hessian functions. To do that, we first calculate the following partial derivatives of a perspective function, which are:
# \begin{align*}
# \frac{\partial}{\partial x}\left(\lambda \phi^*\left(\frac{x}{\lambda}\right)\right)&=(\phi^*)'\left(\frac{x}{\lambda}\right)\\
# \frac{\partial}{\partial\lambda}\left(\lambda \phi^*\left(\frac{x}{\lambda}\right)\right)&=\phi^*\left(\frac{x}{\lambda}\right)-(\phi^*)'\left(\frac{x}{\lambda}\right)\cdot \frac{x}{\lambda}
# \end{align*}
#
# as well as the second partial derivatives:
# \begin{align*}
# \frac{\partial^2}{\partial x^2}\left(\lambda \phi^*\left(\frac{x}{\lambda}\right)\right)&=(\phi^*)''\left(\frac{x}{\lambda}\right)\cdot \frac{1}{\lambda}\\
# \frac{\partial^2}{\partial\lambda^2}\left(\lambda \phi^*\left(\frac{x}{\lambda}\right)\right)&=(\phi^*)''\left(\frac{x}{\lambda}\right)\cdot \frac{x^2}{\lambda^3}\\
# \frac{\partial^2}{\partial x\partial\lambda}\left(\lambda \phi^*\left(\frac{x}{\lambda}\right)\right)&=(\phi^*)''\left(\frac{x}{\lambda}\right)\cdot -\frac{x}{\lambda^2}.
# \end{align*}

# %%
##### Ipopt with dummy variables


class MyOpti(cyipopt.Problem):     #### The above parameters are defined as global variables here, there is probably
                                        ####    a better way of doing this.
    
    def objective(self, x):
        """Returns the scalar value of the objective given x."""
        
        the1 = x[0]
        the2 = x[1]
        lbda = x[2]
        N = len(X)
        f_som = 0
        for i in range(3,N+3):
            f_som = f_som + lbda * f_explog((x[i]+the1)/lbda,a,b)
        return(f_som/N - the1 - the2 + lbda*r)

    def gradient(self, x):
        """Returns the gradient of the objective with respect to x."""
        
        the1 = x[0]
        the2 = x[1]
        lbda = x[2]
        N = len(X)
        grad = np.zeros(N+3)
        grad[1] = -1
        s1 = 0
        s2 = 0  
        for i in range(3,N+3):
            grad[i] = df_explog((x[i]+the1)/lbda,a,b)/N
            s1 = s1 + df_explog((x[i]+the1)/lbda,a,b)
            s2 = s2 + f_explog((x[i]+the1)/lbda,a,b) - df_explog((x[i]+the1)/lbda,a,b) * ((x[i]+the1)/lbda)
        grad[0] = -1 + s1/N
        grad[2] = r + s2/N
        return(grad)
             
        
       
    def constraints(self, x):
        """Returns the constraints."""
        
        N = len(X)
        cons = np.zeros(N)
        for i in range(N):
            cons[i] = 1/alpha * (x[1]-X[i])-x[i+3] 
        
        return(cons)

    
    def jacobian(self, x):
        """Returns the Jacobian of the constraints with respect to x."""
        
        N = len(X)
        jacob = np.zeros(N+3)
        jacob[1] = 1/alpha
        for i in range(3,N+3):
            jacob[i] = -1
        jacob = np.array([jacob])
        
        row, col = self.jacobianstructure()
        return(jacob[row,col])
        
        
    def jacobianstructure(self):
        N = len(X)
        jac_struc = np.zeros(N+3)+1
        jac_struc[0] = 0
        jac_struc[2] = 0
        jac_struc = np.array([jac_struc])
        return(np.nonzero(jac_struc))
    
    
    def hessianstructure(self):
        """Returns the row and column indices for non-zero vales of the
        Hessian."""

        # NOTE: The default hessian structure is of a lower triangular matrix,
        # therefore this function is redundant. It is included as an example
        # for structure callback.
       
        N = len(X)
        struc = np.tril(np.ones((N+3,N+3)))
        struc[1,:] = 0
        struc[0:N+3,1] = 0
        for i in range(3,N+1):
            struc[(i+1):(N+3),i] = 0
        struc[N+2,N+1] = 0
        return np.nonzero(struc)

    def hessian(self, x, lagrange, obj_factor):
        """Returns the non-zero values of the Hessian."""
        
        N = len(X)
        H = np.zeros((N+3,N+3))
        the1 = x[0]
        the2 = x[1]
        lbda = x[2]
        H00 = 0
        H20 = 0
        H22 = 0
        for i in range(3,N+3):
            H00 = H00 + ddf_explog((x[i]+the1)/lbda,a,b) * 1/lbda
            H20 = H20 - ddf_explog((x[i]+the1)/lbda,a,b) * (x[i]+the1)/lbda**2
            H22 = H22 + ddf_explog((x[i]+the1)/lbda,a,b) * ((x[i]+the1)**2)/lbda**3
            H[i,0] = ddf_explog((x[i]+the1)/lbda,a,b) * 1/lbda * 1/N
            H[i,2] = -ddf_explog((x[i]+the1)/lbda,a,b) * (x[i]+the1)/lbda**2 * 1/N
            H[i,i] = ddf_explog((x[i]+the1)/lbda,a,b) * 1/lbda * 1/N
        
        H[0,0] = H00/N
        H[2,0] = H20/N
        H[2,2] = H22/N        

        H = obj_factor*H

        row, col = self.hessianstructure()

        return H[row, col]


    def intermediate(self, alg_mod, iter_count, obj_value, inf_pr, inf_du, mu,
                     d_norm, regularization_size, alpha_du, alpha_pr,
                     ls_trials):
        """Prints information at every Ipopt iteration."""

        iterate = self.get_current_iterate()
        infeas = self.get_current_violations()
        primal = iterate["x"]
        jac = self.jacobian(primal)
        msg = "Objective value at iteration #{:d} is - {:g}"

        print(msg.format(iter_count, obj_value))
        print("Primal iterate:", primal[0:3])
        print('inf_pr:', inf_pr)

# %% [markdown]
# Below we define the bounds on the variables and the constraints:

# %%
lb = [-30,-30,0.01]
ub = [30, 30, 100]


cl = []
cu = []
x0 = [0.5,-2,1]
N = len(X)
for i in range(3, N+3):
    lb.append(0.01)
    ub.append(1000)
    cl.append(-100000)
    cu.append(0.01)
    x0.append(np.maximum(1/alpha*(x0[1]-X[i-3]),0)+0.001)

# %% [markdown]
# We define the problem for ipopt

# %%
nlp = MyOpti(
    n=len(x0),
    m=len(cl),
    lb=lb,
    ub=ub,
    cl=cl,
    cu=cu,
)
nlp.add_option('tol', 1e-6)
nlp.add_option('max_iter', 4000)

# %%
#### running ipopt

x, info = nlp.solve(x0)
# Out:
# Objective value at iteration #0 is - 106.388
# Primal iterate: [ 0.5 -2.   1. ]
# inf_pr: 0.0
# Objective value at iteration #1 is - 14.4844
# Primal iterate: [-3.72405971 -6.49660426  0.6212739 ]
# inf_pr: 90.13028239611201
# Objective value at iteration #2 is - 13.1334
# Primal iterate: [-2.62034774 -1.18474468  0.79219166]
# inf_pr: 82.35638030344893
# Objective value at iteration #3 is - 7.85405
# Primal iterate: [-7.57559684 -0.28978252  0.01782191]
# inf_pr: 83.33370751680778
# Objective value at iteration #4 is - 7.41713
# Primal iterate: [-7.50308247  0.07468574  0.01921044]
# inf_pr: 89.66281918611102
# Objective value at iteration #5 is - 7.41324
# Primal iterate: [-7.50352839  0.07944634  0.01932621]
# inf_pr: 89.65267514418721
# Objective value at iteration #6 is - 7.75652
# Primal iterate: [-7.55622058  0.12879945  0.01983158]
# inf_pr: 88.76820283255873
# Objective value at iteration #7 is - 7.77886
# Primal iterate: [-7.62512953  0.16063682  0.01948105]
# inf_pr: 87.89579537277261
# Objective value at iteration #8 is - 7.76661
# Primal iterate: [-7.62607425  0.17391015  0.01947974]
# inf_pr: 87.88760123655524
# Objective value at iteration #9 is - 7.88409
# Primal iterate: [-8.00060918  0.40024144  0.01914893]
# inf_pr: 88.31645835130115
# Objective value at iteration #10 is - 7.88542
# Primal iterate: [-8.00449897  0.40253113  0.01914693]
# inf_pr: 88.32114447673952
# Objective value at iteration #11 is - 7.88542
# Primal iterate: [-8.00449897  0.40253113  0.01914693]
# inf_pr: 88.32114447673952
# Objective value at iteration #12 is - 30.7934
# Primal iterate: [-7.99728108  0.05162069  0.02622523]
# inf_pr: 80.13974080137116
# Objective value at iteration #13 is - 53.3302
# Primal iterate: [-6.1025189   1.46474289  0.42849743]
# inf_pr: 105.6876624586281
# Objective value at iteration #14 is - 40.3158
# Primal iterate: [-5.47518908  1.90637795  1.62896218]
# inf_pr: 111.56256986437441
# Objective value at iteration #15 is - 156.529
# Primal iterate: [-3.62884006 -3.56852739  2.76219207]
# inf_pr: 242.04903568458283
# Objective value at iteration #16 is - 156.754
# Primal iterate: [-3.67947267 -3.60346765  2.72656177]
# inf_pr: 231.7019334305362
# Objective value at iteration #17 is - 157.099
# Primal iterate: [-3.68402781 -3.62048111  2.72345531]
# inf_pr: 230.10553903316173
# Objective value at iteration #18 is - 159.962
# Primal iterate: [-3.72158559 -3.75946889  2.69788446]
# inf_pr: 216.99887008015673
# Objective value at iteration #19 is - 160.013
# Primal iterate: [-3.72226275 -3.76182999  2.69742855]
# inf_pr: 216.76875571030394
# Objective value at iteration #20 is - 161.221
# Primal iterate: [-3.7385352  -3.81825029  2.68648157]
# inf_pr: 211.25304011637712
# Objective value at iteration #21 is - 161.243
# Primal iterate: [-3.73882901 -3.81924161  2.6862849 ]
# inf_pr: 211.15463611498723
# Objective value at iteration #22 is - 161.356
# Primal iterate: [-3.74037889 -3.82444893  2.685248  ]
# inf_pr: 210.636516539369
# Objective value at iteration #23 is - 161.408
# Primal iterate: [-3.74108688 -3.82681804  2.68477465]
# inf_pr: 210.40025938630163
# Objective value at iteration #24 is - 162.236
# Primal iterate: [-3.75243069 -3.86465304  2.6771941 ]
# inf_pr: 206.62027852916634
# Objective value at iteration #25 is - 162.25
# Primal iterate: [-3.75262566 -3.86528986  2.67706429]
# inf_pr: 206.5558980884503
# Objective value at iteration #26 is - 162.495
# Primal iterate: [-3.75601339 -3.87630821  2.67480998]
# inf_pr: 205.43932277574928
# Objective value at iteration #27 is - 162.506
# Primal iterate: [-3.75617503 -3.87683037  2.67470255]
# inf_pr: 205.38620352645106
# Objective value at iteration #28 is - 163.413
# Primal iterate: [-3.76876403 -3.91739431  2.66633794]
# inf_pr: 201.25369566556714
# Objective value at iteration #29 is - 163.424
# Primal iterate: [-3.76892514 -3.91790234  2.6662313 ]
# inf_pr: 201.2012954939045
# Objective value at iteration #30 is - 163.81
# Primal iterate: [-3.77436573 -3.93489862  2.66263444]
# inf_pr: 199.43884903266
# Objective value at iteration #31 is - 163.817
# Primal iterate: [-3.77446674 -3.93521094  2.66256778]
# inf_pr: 199.40626981898026
# Objective value at iteration #32 is - 165.761
# Primal iterate: [-3.8019402  -4.01975101  2.64444764]
# inf_pr: 190.56328889836283
# Objective value at iteration #33 is - 165.781
# Primal iterate: [-3.8022287  -4.02059812  2.6442589 ]
# inf_pr: 190.47221702690658
# Objective value at iteration #34 is - 165.942
# Primal iterate: [-3.80467226 -4.02724817  2.64267509]
# inf_pr: 189.72452373667932
# Objective value at iteration #35 is - 165.962
# Primal iterate: [-3.80497887 -4.02807744  2.64247654]
# inf_pr: 189.63093913329496
# Objective value at iteration #36 is - 168.366
# Primal iterate: [-3.84146838 -4.12640652  2.61885938]
# inf_pr: 178.50996003746513
# Objective value at iteration #37 is - 168.392
# Primal iterate: [-3.84187877 -4.12744464  2.61859656]
# inf_pr: 178.3879490919214
# Objective value at iteration #38 is - 169.739
# Primal iterate: [-3.86341814 -4.17983795  2.60486579]
# inf_pr: 172.07971956624823
# Objective value at iteration #39 is - 169.753
# Primal iterate: [-3.86364107 -4.18035938  2.60472457]
# inf_pr: 172.0153896666726
# Objective value at iteration #40 is - 175.229
# Primal iterate: [-3.95446859 -4.38127175  2.54755282]
# inf_pr: 146.33858768037027
# Objective value at iteration #41 is - 175.283
# Primal iterate: [-3.95544099 -4.38307894  2.54695637]
# inf_pr: 146.0796496600753
# Objective value at iteration #42 is - 179.369
# Primal iterate: [-4.05563641 -4.49433417  2.48860535]
# inf_pr: 123.17607352766035
# Objective value at iteration #43 is - 179.409
# Primal iterate: [-4.05671081 -4.49530665  2.48799364]
# inf_pr: 122.9419824568289
# Objective value at iteration #44 is - 185.974
# Primal iterate: [-4.28429003 -4.61354335  2.36340619]
# inf_pr: 78.12656629301742
# Objective value at iteration #44 is - 185.974
# Primal iterate: [-4.28429003 -4.61354335  2.36340619]
# inf_pr: 78.12656629301742
# Objective value at iteration #45 is - 37.7048
# Primal iterate: [-29.7428432   -7.41801184   0.46220101]
# inf_pr: 54.844352809079396
# Objective value at iteration #46 is - 38.2374
# Primal iterate: [-29.71414339  -8.35413048   0.48098151]
# inf_pr: 18.584555287129604
# Objective value at iteration #47 is - 37.5362
# Primal iterate: [-29.61273768  -7.8228041    0.61261519]
# inf_pr: 10.996204804375054
# Objective value at iteration #48 is - 35.3426
# Primal iterate: [-29.24442121  -5.92082483   1.37470558]
# inf_pr: 38.34302214402547
# Objective value at iteration #49 is - 32.2298
# Primal iterate: [-28.68832068  -2.79906878   6.26171417]
# inf_pr: 3.9341911734652797
# Objective value at iteration #50 is - 32.2298
# Primal iterate: [-28.68832068  -2.79906878   6.26171417]
# inf_pr: 3.9341911734652797
# Objective value at iteration #51 is - 32.2322
# Primal iterate: [-28.67494639  -2.79700789   6.26451639]
# inf_pr: 3.003352736180115
# Objective value at iteration #51 is - 32.2322
# Primal iterate: [-28.67494639  -2.79700789   6.26451639]
# inf_pr: 3.003352736180115
# Objective value at iteration #52 is - 32.2322
# Primal iterate: [-28.67494639  -2.79700789   6.26451639]
# inf_pr: 3.003352736180115
# Objective value at iteration #53 is - 32.2353
# Primal iterate: [-28.66918955  -2.79619723   6.26599038]
# inf_pr: 3.00685828505445
# Objective value at iteration #54 is - 110.441
# Primal iterate: [-23.42658489  -6.77962569   7.47460344]
# inf_pr: 430.78230772304346
# Objective value at iteration #55 is - 114.168
# Primal iterate: [-22.92560244  -6.75022151   7.57157898]
# inf_pr: 429.1764623310875
# Objective value at iteration #56 is - 114.205
# Primal iterate: [-22.92056561  -6.74998307   7.57258963]
# inf_pr: 429.15459440704836
# Objective value at iteration #57 is - 114.593
# Primal iterate: [-22.86714154  -6.74749396   7.58338413]
# inf_pr: 428.9125073978172
# Objective value at iteration #58 is - 255.604
# Primal iterate: [-6.09210204 -5.9744546  10.97443707]
# inf_pr: 352.27826207465614
# Objective value at iteration #59 is - 402.043
# Primal iterate: [ -6.66381362 -11.0379826   11.3978416 ]
# inf_pr: 50.63023517971402
# Objective value at iteration #60 is - 361.123
# Primal iterate: [ -6.62341304 -10.28050192  11.44331026]
# inf_pr: 99.74566670758253
# Objective value at iteration #61 is - 312.725
# Primal iterate: [-6.6240489  -8.88521488 11.44442064]
# inf_pr: 126.47974991228571
# Objective value at iteration #62 is - 276.316
# Primal iterate: [-6.62404889 -7.72008658 11.44442057]
# inf_pr: 101.1625773800758
# Objective value at iteration #63 is - 251.656
# Primal iterate: [-6.62404889 -6.86553346 11.44442057]
# inf_pr: 71.96790805039569
# Objective value at iteration #64 is - 235.906
# Primal iterate: [-6.62404889 -6.28775156 11.44442057]
# inf_pr: 47.62458296434038
# Objective value at iteration #65 is - 226.303
# Primal iterate: [-6.62404889 -5.92216531 11.44442057]
# inf_pr: 29.735825573067572
# Objective value at iteration #66 is - 204.179
# Primal iterate: [-9.87302962 -7.02202519  9.11306552]
# inf_pr: 125.35307862123966
# Objective value at iteration #67 is - 171.908
# Primal iterate: [-10.72596351  -5.73421344   9.20931949]
# inf_pr: 83.36998089328557
# Objective value at iteration #68 is - 158.207
# Primal iterate: [-10.8957853   -5.28859727   9.22876914]
# inf_pr: 42.77188754728828
# Objective value at iteration #69 is - 150.827
# Primal iterate: [-10.89718696  -4.99358503   9.2287388 ]
# inf_pr: 25.467131139681605
# Objective value at iteration #70 is - 146.428
# Primal iterate: [-10.89718698  -4.81230818   9.2287388 ]
# inf_pr: 15.467817488735598
# Objective value at iteration #71 is - 143.826
# Primal iterate: [-10.89718698  -4.70347935   9.2287388 ]
# inf_pr: 9.254653210673304
# Objective value at iteration #72 is - 142.301
# Primal iterate: [-10.89718698  -4.6391884    9.2287388 ]
# inf_pr: 5.457557649324507
# Objective value at iteration #73 is - 120.055
# Primal iterate: [-14.76295708  -5.26609829   7.74825913]
# inf_pr: 76.85770452368813
# Objective value at iteration #74 is - 104.309
# Primal iterate: [-15.25292625  -4.51717367   7.8405107 ]
# inf_pr: 50.12199430577509
# Objective value at iteration #75 is - 98.2977
# Primal iterate: [-15.41194109  -4.29432709   7.85154873]
# inf_pr: 21.998842445537434
# Objective value at iteration #76 is - 95.3169
# Primal iterate: [-15.41297391  -4.1579532    7.85153599]
# inf_pr: 12.406308534806683
# Objective value at iteration #77 is - 93.5504
# Primal iterate: [-15.41297394  -4.07561626   7.85153599]
# inf_pr: 7.454160792195438
# Objective value at iteration #78 is - 92.4999
# Primal iterate: [-15.41297394  -4.02620482   7.85153599]
# inf_pr: 4.467690943974063
# Objective value at iteration #79 is - 91.8787
# Primal iterate: [-15.41297394  -3.99683246   7.85153599]
# inf_pr: 2.6538991500873834
# Objective value at iteration #79 is - 91.8787
# Primal iterate: [-15.41297394  -3.99683246   7.85153599]
# inf_pr: 2.6538991500873834
# Objective value at iteration #80 is - 91.5174
# Primal iterate: [-15.46981052  -4.15188278   7.79088661]
# inf_pr: 5.644687766207113
# Objective value at iteration #81 is - 91.4712
# Primal iterate: [-15.47678496  -4.1713988    7.78336407]
# inf_pr: 6.023884558569463
# Objective value at iteration #82 is - 91.4637
# Primal iterate: [-15.47783663  -4.17407304   7.78242466]
# inf_pr: 6.07750210453883
# Objective value at iteration #83 is - 91.4584
# Primal iterate: [-15.47847349  -4.17563357   7.78199848]
# inf_pr: 6.109114457321695
# Objective value at iteration #84 is - 55.1124
# Primal iterate: [-26.26741827 -29.74175663   0.90583154]
# inf_pr: 525.2130307035453
# Objective value at iteration #85 is - 51.0844
# Primal iterate: [-24.16550804 -28.17504181   1.26880195]
# inf_pr: 471.712197886967
# Objective value at iteration #86 is - 18.7229
# Primal iterate: [-18.20044555  -2.65267782   2.15316488]
# inf_pr: 508.5973452161014
# Objective value at iteration #87 is - 6.48936
# Primal iterate: [-5.47918077  1.02586696  3.57211541]
# inf_pr: 106.46685330113657
# Objective value at iteration #88 is - 6.65826
# Primal iterate: [-11.43159079   6.69991867   3.53933517]
# inf_pr: 209.3548670826964
# Objective value at iteration #89 is - 6.65826
# Primal iterate: [-11.43159079   6.69991867   3.53933517]
# inf_pr: 209.3548670826964
# Objective value at iteration #90 is - 7.61135
# Primal iterate: [-11.42571181   5.97519973   3.54420593]
# inf_pr: 201.35395966362324
# Objective value at iteration #91 is - 7.79649
# Primal iterate: [-11.42554299   5.82975907   3.54434302]
# inf_pr: 198.29701036407263
# Objective value at iteration #92 is - 9.3857
# Primal iterate: [-11.39746309   4.67354546   3.56223283]
# inf_pr: 173.88673129359074
# Objective value at iteration #93 is - 14.0954
# Primal iterate: [-10.43987611   5.72910314   4.22770512]
# inf_pr: 191.2811258757302
# Objective value at iteration #94 is - 26.4606
# Primal iterate: [-9.62418544  1.39353754  4.94606113]
# inf_pr: 202.13343747272012
# Objective value at iteration #95 is - 65.2145
# Primal iterate: [-6.3261266  -0.23946266  7.55412633]
# inf_pr: 219.19933061197133
# Objective value at iteration #96 is - 69.8748
# Primal iterate: [-6.23393582 -3.10276198  7.651286  ]
# inf_pr: 142.41916876646044
# Objective value at iteration #96 is - 69.8748
# Primal iterate: [-6.23393582 -3.10276198  7.651286  ]
# inf_pr: 142.41916876646044
# Objective value at iteration #97 is - 55.1944
# Primal iterate: [-8.27993514  2.414208    6.36490058]
# inf_pr: 108.68234392762209
# Objective value at iteration #98 is - 54.6573
# Primal iterate: [-8.51785496  2.30967031  6.26964793]
# inf_pr: 106.4881702818286
# Objective value at iteration #99 is - 54.6552
# Primal iterate: [-8.51856864  2.30917768  6.26940609]
# inf_pr: 106.47674308371833
# Objective value at iteration #100 is - 54.6552
# Primal iterate: [-8.51856864  2.30917768  6.26940609]
# inf_pr: 106.47674308371833
# Objective value at iteration #101 is - 72.9148
# Primal iterate: [-8.50146443  1.76844929  6.28895471]
# inf_pr: 91.44999760509504
# Objective value at iteration #101 is - 72.9148
# Primal iterate: [-8.50146443  1.76844929  6.28895471]
# inf_pr: 91.44999760509504
# Objective value at iteration #102 is - 72.9148
# Primal iterate: [-8.50146443  1.76844929  6.28895471]
# inf_pr: 91.44999760509504
# Objective value at iteration #103 is - 88.3513
# Primal iterate: [-8.49017875  0.95407752  6.3295628 ]
# inf_pr: 72.1183372592422
# Objective value at iteration #104 is - 87.2142
# Primal iterate: [-8.38858108  1.11854905  6.68370185]
# inf_pr: 75.0943901632368
# Objective value at iteration #105 is - 470.43
# Primal iterate: [ -5.53925954 -11.51701033  12.34099933]
# inf_pr: 1328.0904934138534
# Objective value at iteration #106 is - 470.496
# Primal iterate: [ -5.53853689 -11.5139978   12.34314925]
# inf_pr: 1328.0046540826932
# Objective value at iteration #107 is - 472.008
# Primal iterate: [ -5.52209457 -11.44545087  12.39208321]
# inf_pr: 1326.0450519597018
# Objective value at iteration #108 is - 472.032
# Primal iterate: [ -5.52183085 -11.44435231  12.39286915]
# inf_pr: 1326.012969570591
# Objective value at iteration #109 is - 472.302
# Primal iterate: [ -5.51890459 -11.43216174  12.401592  ]
# inf_pr: 1325.6563166073379
# Objective value at iteration #110 is - 472.328
# Primal iterate: [ -5.51861754 -11.43096607  12.40244792]
# inf_pr: 1325.621187441335
# Objective value at iteration #111 is - 472.884
# Primal iterate: [ -5.51258301 -11.40582924  12.42044381]
# inf_pr: 1324.8818864525074
# Objective value at iteration #112 is - 472.902
# Primal iterate: [ -5.51238034 -11.40498525  12.42104855]
# inf_pr: 1324.8568580570334
# Objective value at iteration #113 is - 474.378
# Primal iterate: [ -5.49634898 -11.33822233  12.46889047]
# inf_pr: 1322.8748684809889
# Objective value at iteration #114 is - 474.398
# Primal iterate: [ -5.4961365  -11.33733809  12.46952546]
# inf_pr: 1322.8480759684553
# Objective value at iteration #115 is - 479.402
# Primal iterate: [ -5.44183118 -11.11133172  12.63186216]
# inf_pr: 1315.9833507630754
# Objective value at iteration #116 is - 479.454
# Primal iterate: [ -5.44126976 -11.10900138  12.63354809]
# inf_pr: 1315.9077148023957
# Objective value at iteration #117 is - 481.619
# Primal iterate: [ -5.41773399 -11.01121679  12.70442219]
# inf_pr: 1312.6718185787565
# Objective value at iteration #118 is - 481.644
# Primal iterate: [ -5.41747147 -11.0101273   12.70521431]
# inf_pr: 1312.634753635085
# Objective value at iteration #119 is - 481.834
# Primal iterate: [ -5.41540005 -11.00152847  12.71146905]
# inf_pr: 1312.3407787727085
# Objective value at iteration #120 is - 481.857
# Primal iterate: [ -5.41515593 -11.00051516  12.71220635]
# inf_pr: 1312.3060389965171
# Objective value at iteration #121 is - 483.404
# Primal iterate: [ -5.39834885 -10.9307499   12.7629732 ]
# inf_pr: 1309.9122301598231
# Objective value at iteration #122 is - 483.422
# Primal iterate: [ -5.39815314 -10.92993813  12.76356524]
# inf_pr: 1309.883822477002
# Objective value at iteration #123 is - 483.854
# Primal iterate: [ -5.39346011 -10.91046896  12.77776925]
# inf_pr: 1309.2001193420442
# Objective value at iteration #124 is - 483.864
# Primal iterate: [ -5.39334774 -10.91000287  12.77810951]
# inf_pr: 1309.1836579114529
# Objective value at iteration #125 is - 485.464
# Primal iterate: [ -5.3759786  -10.83795745  12.83071032]
# inf_pr: 1306.6367763613785
# Objective value at iteration #126 is - 485.482
# Primal iterate: [ -5.37578239 -10.83714423  12.83130543]
# inf_pr: 1306.607450469223
# Objective value at iteration #127 is - 486.161
# Primal iterate: [ -5.36840851 -10.8065752   12.85368487]
# inf_pr: 1305.5004887524265
# Objective value at iteration #128 is - 486.172
# Primal iterate: [ -5.36829404 -10.80610082  12.85403252]
# inf_pr: 1305.4831625922811
# Objective value at iteration #129 is - 489.588
# Primal iterate: [ -5.33121227 -10.65241323  12.96667465]
# inf_pr: 1299.8621518790906
# Objective value at iteration #130 is - 489.624
# Primal iterate: [ -5.33082726 -10.65082033  12.96784793]
# inf_pr: 1299.8014490225657
# Objective value at iteration #131 is - 489.905
# Primal iterate: [ -5.32777399 -10.6381762   12.97717373]
# inf_pr: 1299.3128853089274
# Objective value at iteration #132 is - 489.923
# Primal iterate: [ -5.32757382 -10.63734732  12.97778534]
# inf_pr: 1299.2807410154094
# Objective value at iteration #133 is - 494.234
# Primal iterate: [ -5.28067474 -10.44314619  13.12109365]
# inf_pr: 1291.7438663016037
# Objective value at iteration #134 is - 494.279
# Primal iterate: [ -5.2801911  -10.44114794  13.12257754]
# inf_pr: 1291.6623191453386
# Objective value at iteration #135 is - 496.763
# Primal iterate: [ -5.2530738  -10.32895035  13.2060393 ]
# inf_pr: 1287.0011450953023
# Objective value at iteration #136 is - 496.789
# Primal iterate: [ -5.25278214 -10.32774512  13.20693909]
# inf_pr: 1286.9496470431943
# Objective value at iteration #137 is - 504.981
# Primal iterate: [-5.16338372 -9.95812954 13.48304946]
# inf_pr: 1271.058300139861
# Objective value at iteration #138 is - 505.066
# Primal iterate: [-5.16247094 -9.9543719  13.48589102]
# inf_pr: 1270.8814669662695
# Objective value at iteration #139 is - 514.91
# Primal iterate: [-5.05249453 -9.4990285  13.83190612]
# inf_pr: 1248.3003891442486
# Objective value at iteration #140 is - 515.014
# Primal iterate: [-5.05136439 -9.49437318 13.83549643]
# inf_pr: 1248.0446299987898
# Objective value at iteration #141 is - 530.752
# Primal iterate: [-4.87134505 -8.74730694 14.41394238]
# inf_pr: 1204.9214592388016
# Objective value at iteration #142 is - 530.924
# Primal iterate: [-4.86946511 -8.73957127 14.42008231]
# inf_pr: 1204.3988603509665
# Objective value at iteration #143 is - 666.533
# Primal iterate: [-3.17813105 -1.60636473 20.10515239]
# inf_pr: 670.3318034918243
# Objective value at iteration #144 is - 738.214
# Primal iterate: [-3.34172858 -2.86479985 20.23884594]
# inf_pr: 182.74080873933582
# Objective value at iteration #145 is - 797.97
# Primal iterate: [-4.75849099 -4.1720264  15.23376642]
# inf_pr: 155.89003114793428
# Objective value at iteration #146 is - 767.426
# Primal iterate: [-5.44921258 -4.00170516 14.08155776]
# inf_pr: 141.765784369696
# Objective value at iteration #147 is - 788.714
# Primal iterate: [-6.41496956 -3.83616236 12.04923938]
# inf_pr: 118.04244215841044
# Objective value at iteration #148 is - 742.117
# Primal iterate: [-6.43085171 -3.48657644 11.83306173]
# inf_pr: 103.93270306299955
# Objective value at iteration #149 is - 693.381
# Primal iterate: [-6.43086679 -3.16799012 11.83047586]
# inf_pr: 91.3119773898119
# Objective value at iteration #150 is - 651.858
# Primal iterate: [-6.43086679 -2.88626879 11.83047549]
# inf_pr: 80.02981564832774
# Objective value at iteration #151 is - 616.553
# Primal iterate: [-6.43086679 -2.63815935 11.83047549]
# inf_pr: 69.96397083809603
# Objective value at iteration #152 is - 586.529
# Primal iterate: [-6.43086679 -2.42031644 11.83047549]
# inf_pr: 61.00500936315102
# Objective value at iteration #153 is - 560.995
# Primal iterate: [-6.43086679 -2.22963692 11.83047549]
# inf_pr: 53.0531615793047
# Objective value at iteration #154 is - 539.282
# Primal iterate: [-6.43086679 -2.06325237 11.83047549]
# inf_pr: 46.01664813335762
# Objective value at iteration #155 is - 520.824
# Primal iterate: [-6.43086679 -1.91851482 11.83047549]
# inf_pr: 39.81040742387102
# Objective value at iteration #156 is - 505.139
# Primal iterate: [-6.43086679 -1.79298644 11.83047549]
# inf_pr: 34.35514941836384
# Objective value at iteration #157 is - 571.046
# Primal iterate: [-7.65517262 -2.31445404  8.97239903]
# inf_pr: 72.30412669737322
# Objective value at iteration #158 is - 524.192
# Primal iterate: [-7.42014568 -1.90176467  9.3934309 ]
# inf_pr: 56.07919331780454
# Objective value at iteration #159 is - 498.638
# Primal iterate: [-7.41632025 -1.75579042  9.48609008]
# inf_pr: 43.10620731035344
# Objective value at iteration #160 is - 480.032
# Primal iterate: [-7.41632119 -1.62623694  9.48542912]
# inf_pr: 37.67714908244343
# Objective value at iteration #161 is - 463.941
# Primal iterate: [-7.41632119 -1.51200965  9.48542909]
# inf_pr: 33.101140923837534
# Objective value at iteration #162 is - 450.033
# Primal iterate: [-7.41632119 -1.41144533  9.48542909]
# inf_pr: 29.05322264700298
# Objective value at iteration #163 is - 438.005
# Primal iterate: [-7.41632119 -1.32303554  9.48542909]
# inf_pr: 25.470666419535807
# Objective value at iteration #164 is - 427.598
# Primal iterate: [-7.41632119 -1.24541715  9.48542909]
# inf_pr: 22.304977304486904
# Objective value at iteration #165 is - 418.593
# Primal iterate: [-7.41632119 -1.17736077  9.48542909]
# inf_pr: 19.512224152807963
# Objective value at iteration #166 is - 410.797
# Primal iterate: [-7.41632119 -1.11776051  9.48542909]
# inf_pr: 17.05239932229374
# Objective value at iteration #167 is - 404.046
# Primal iterate: [-7.41632119 -1.06562423  9.48542909]
# inf_pr: 14.889129602821363
# Objective value at iteration #167 is - 404.046
# Primal iterate: [-7.41632119 -1.06562423  9.48542909]
# inf_pr: 14.889129602821363
# Objective value at iteration #168 is - 398.718
# Primal iterate: [-8.11500376 -1.21433756  9.44961459]
# inf_pr: 17.72688276804523
# Objective value at iteration #169 is - 398.031
# Primal iterate: [-8.19963715 -1.24319671  9.44397122]
# inf_pr: 18.277907134914873
# Objective value at iteration #170 is - 397.773
# Primal iterate: [-8.22071367 -1.26247205  9.44237347]
# inf_pr: 18.646302214972305
# Objective value at iteration #171 is - 66.0059
# Primal iterate: [-29.78220743 -10.02433481   5.61717109]
# inf_pr: 152.1302719916261
# Objective value at iteration #172 is - 46.6947
# Primal iterate: [-29.82165878 -10.26989984   4.96035466]
# inf_pr: 152.2693176938183
# Objective value at iteration #173 is - 40.6914
# Primal iterate: [-29.79737108 -10.95296503   0.05950354]
# inf_pr: 166.06751140128497
# Objective value at iteration #174 is - 39.2321
# Primal iterate: [-29.77364298  -8.4190003    0.10220769]
# inf_pr: 117.78737003315054
# Objective value at iteration #175 is - 38.6018
# Primal iterate: [-2.97751761e+01 -8.71796183e+00  1.09220670e-02]
# inf_pr: 123.43272525075746
# Objective value at iteration #176 is - 36.2216
# Primal iterate: [-29.58696419  -3.47859507   0.33188539]
# inf_pr: 22.064411658631116
# Objective value at iteration #177 is - 34.6383
# Primal iterate: [-28.20949915  -5.79489827   0.0543012 ]
# inf_pr: 65.34130066427026
# Objective value at iteration #178 is - 48.6
# Primal iterate: [-28.05548661  -3.58008892   0.05391579]
# inf_pr: 23.37501087214912
# Objective value at iteration #179 is - 35.3911
# Primal iterate: [-2.84144273e+01 -4.36081160e+00  1.04391480e-02]
# inf_pr: 38.15000273723572
# Objective value at iteration #180 is - 31.1121
# Primal iterate: [-2.86119611e+01 -2.50631895e+00  1.04430890e-02]
# inf_pr: 37.18791984021463
# Objective value at iteration #181 is - 31.0724
# Primal iterate: [-2.85831143e+01 -2.48572935e+00  1.07863631e-02]
# inf_pr: 10.234688397074194
# Objective value at iteration #182 is - 31.0717
# Primal iterate: [-2.85828991e+01 -2.48489151e+00  1.20356694e-02]
# inf_pr: 9.977582987596307
# Objective value at iteration #183 is - 31.0717
# Primal iterate: [-2.85828991e+01 -2.48489151e+00  1.20356694e-02]
# inf_pr: 9.977582987596307
# Objective value at iteration #184 is - 31.1232
# Primal iterate: [-28.45533245  -2.47463206   0.27516156]
# inf_pr: 10.167536697556514
# Objective value at iteration #185 is - 11396.5
# Primal iterate: [-18.76528446 -17.07942251   0.2876535 ]
# inf_pr: 1401.9799780239405
# Objective value at iteration #186 is - 11529.7
# Primal iterate: [-17.96171542 -16.86781935   0.28982911]
# inf_pr: 1363.839227534072
# Objective value at iteration #187 is - 11530.8
# Primal iterate: [-17.9540364  -16.86568108   0.28985248]
# inf_pr: 1363.4520967050644
# Objective value at iteration #188 is - 11542.6
# Primal iterate: [-17.86519778 -16.83988392   0.29014907]
# inf_pr: 1358.765897962951
# Objective value at iteration #189 is - 14950.8
# Primal iterate: [ 8.02805778 -9.29989535  0.37713496]
# inf_pr: 151.41215966248484
# Objective value at iteration #190 is - 8921.58
# Primal iterate: [-5.63509785 -9.01003775  0.43280579]
# inf_pr: 74.73627295801896
# Objective value at iteration #191 is - 3059.76
# Primal iterate: [-7.55957422 -9.9464315   0.89546565]
# inf_pr: 209.50699869893222
# Objective value at iteration #192 is - 2017.96
# Primal iterate: [-7.63034534 -7.98710699  1.10559671]
# inf_pr: 152.55797895068667
# Objective value at iteration #193 is - 1599.9
# Primal iterate: [-7.6375937  -7.04681586  1.19584715]
# inf_pr: 106.54869855221995
# Objective value at iteration #194 is - 1418.16
# Primal iterate: [-7.63759742 -6.30474219  1.19243027]
# inf_pr: 77.96560385916912
# Objective value at iteration #195 is - 1291.41
# Primal iterate: [-7.63759742 -5.755951    1.19242536]
# inf_pr: 56.17250003435669
# Objective value at iteration #196 is - 1206.63
# Primal iterate: [-7.63759742 -5.36731097  1.19242536]
# inf_pr: 39.15969660640393
# Objective value at iteration #197 is - 1151.23
# Primal iterate: [-7.63759742 -5.10289763  1.19242536]
# inf_pr: 26.35480822578821
# Objective value at iteration #198 is - 1115.75
# Primal iterate: [-7.63759742 -4.92893532  1.19242536]
# inf_pr: 17.21774507704832
# Objective value at iteration #199 is - 1188.68
# Primal iterate: [-11.08638976  -5.77279602   0.79389447]
# inf_pr: 96.70264679541111
# Objective value at iteration #200 is - 980.935
# Primal iterate: [-11.88169189  -4.92534866   0.79971938]
# inf_pr: 66.4469867146498
# Objective value at iteration #201 is - 887.894
# Primal iterate: [-12.06694002  -4.61273418   0.80266662]
# inf_pr: 36.056868122510366
# Objective value at iteration #202 is - 836.082
# Primal iterate: [-12.06847268  -4.38943138   0.80266116]
# inf_pr: 23.71502071397041
# Objective value at iteration #203 is - 802.133
# Primal iterate: [-12.06847271  -4.2376499    0.80266116]
# inf_pr: 15.969535425599993
# Objective value at iteration #204 is - 780.008
# Primal iterate: [-12.06847271  -4.13653373   0.80266116]
# inf_pr: 10.595629962062617
# Objective value at iteration #205 is - 765.733
# Primal iterate: [-12.06847271  -4.07033871   0.80266116]
# inf_pr: 6.918523033482963
# Objective value at iteration #205 is - 765.733
# Primal iterate: [-12.06847271  -4.07033871   0.80266116]
# inf_pr: 6.918523033482963
# Objective value at iteration #206 is - 760.279
# Primal iterate: [-12.15247226  -4.27053846   0.79653042]
# inf_pr: 10.725190794735973
# Objective value at iteration #207 is - 759.947
# Primal iterate: [-12.15730665  -4.28297604   0.79615801]
# inf_pr: 10.961766398151106
# Objective value at iteration #208 is - 759.926
# Primal iterate: [-12.15761712  -4.28375302   0.79613459]
# inf_pr: 10.976579683440193
# Objective value at iteration #209 is - 759.915
# Primal iterate: [-12.15778044  -4.28414149   0.79612276]
# inf_pr: 10.984080137275612
# Objective value at iteration #210 is - 759.907
# Primal iterate: [-12.15787268  -4.28433572   0.79611829]
# inf_pr: 10.988091138669141
# Objective value at iteration #211 is - 54.6651
# Primal iterate: [-25.12846356 -29.74284365   0.20832966]
# inf_pr: 537.7326330532629
# Objective value at iteration #212 is - 54.1532
# Primal iterate: [-24.91411794 -29.45029195   0.21331236]
# inf_pr: 508.95381949991634
# Objective value at iteration #213 is - 53.3592
# Primal iterate: [-24.89836911 -28.67240841   0.21366791]
# inf_pr: 487.59149949168585
# Objective value at iteration #214 is - 28.7038
# Primal iterate: [-24.56897929  -4.35364647   0.22108079]
# inf_pr: 486.2478334203969
# Objective value at iteration #215 is - 27.7182
# Primal iterate: [-24.20177817  -3.74312538   0.22902376]
# inf_pr: 17.95690400932286
# Objective value at iteration #216 is - 13.0856
# Primal iterate: [-13.66695061   0.30959011   0.27450104]
# inf_pr: 90.12039052242699
# Objective value at iteration #217 is - 8.50929
# Primal iterate: [-10.4770148    1.69583779   0.27462988]
# inf_pr: 116.41337808988342
# Objective value at iteration #218 is - 8.50929
# Primal iterate: [-10.4770148    1.69583779   0.27462988]
# inf_pr: 116.41337808988342
# Objective value at iteration #219 is - 8.81462
# Primal iterate: [-10.47116707   1.37973803   0.27960986]
# inf_pr: 110.80922298749748
# Objective value at iteration #220 is - 8.87402
# Primal iterate: [-10.46913308   1.31756508   0.28034722]
# inf_pr: 109.52049418120649
# Objective value at iteration #221 is - 8.73067
# Primal iterate: [-10.25388863   1.2025801    0.32387739]
# inf_pr: 106.46527455033424
# Objective value at iteration #222 is - 7.74705
# Primal iterate: [-9.13157968  0.74943846  0.74692147]
# inf_pr: 96.18693976354099
# Objective value at iteration #222 is - 7.74705
# Primal iterate: [-9.13157968  0.74943846  0.74692147]
# inf_pr: 96.18693976354099
# Objective value at iteration #223 is - 7.74705
# Primal iterate: [-9.13157968  0.74943846  0.74692147]
# inf_pr: 96.18693976354099
# Objective value at iteration #224 is - 7.74811
# Primal iterate: [-9.13084658  0.74833379  0.74741435]
# inf_pr: 96.15815543314042
# Objective value at iteration #225 is - 7.79487
# Primal iterate: [-9.12999689  0.7153499   0.74797029]
# inf_pr: 95.39737267824515
# Objective value at iteration #226 is - 7.87223
# Primal iterate: [-8.55240438  1.28501491  0.8538915 ]
# inf_pr: 105.44578271615137
# Objective value at iteration #227 is - 10.1749
# Primal iterate: [-8.04911101  1.39112236  1.19799781]
# inf_pr: 106.51467359050113
# Objective value at iteration #228 is - 23.5961
# Primal iterate: [-7.59123239 -0.14101289  1.37033016]
# inf_pr: 144.41498731655957
# Objective value at iteration #229 is - 82.4686
# Primal iterate: [-5.08979225  1.7743583   2.43037455]
# inf_pr: 197.30204914760998
# Objective value at iteration #230 is - 82.2604
# Primal iterate: [-5.08624886  1.71469449  2.43185636]
# inf_pr: 190.6018079649628
# Objective value at iteration #231 is - 81.459
# Primal iterate: [-5.06692942  1.36501023  2.43993576]
# inf_pr: 154.93926680975136
# Objective value at iteration #232 is - 81.4681
# Primal iterate: [-5.06658919  1.35716773  2.44007805]
# inf_pr: 154.3755743266518
# Objective value at iteration #233 is - 82.2414
# Primal iterate: [-5.05159491  0.98560602  2.44634927]
# inf_pr: 130.40930581952782
# Objective value at iteration #234 is - 82.308
# Primal iterate: [-5.05097707  0.96790741  2.44660768]
# inf_pr: 129.49460765523298
# Objective value at iteration #235 is - 82.9603
# Primal iterate: [-5.04718914  0.84369117  2.44819208]
# inf_pr: 124.17390594362377
# Objective value at iteration #236 is - 82.9669
# Primal iterate: [-5.04715643  0.84255822  2.44820576]
# inf_pr: 124.12947032319802
# Objective value at iteration #237 is - 82.985
# Primal iterate: [-5.04706254  0.83936854  2.44824503]
# inf_pr: 124.0076991226221
# Objective value at iteration #238 is - 82.9851
# Primal iterate: [-5.0470622   0.8393558   2.44824518]
# inf_pr: 124.00718708651438
# Objective value at iteration #239 is - 83.0714
# Primal iterate: [-5.0466266   0.82442149  2.44842738]
# inf_pr: 123.4475040306855
# Objective value at iteration #240 is - 83.0715
# Primal iterate: [-5.04662622  0.82440706  2.44842754]
# inf_pr: 123.44691876666397
# Objective value at iteration #241 is - 83.2195
# Primal iterate: [-5.04588629  0.79896251  2.44873705]
# inf_pr: 122.49740091603687
# Objective value at iteration #242 is - 83.4814
# Primal iterate: [-5.04476913  0.75849056  2.44920436]
# inf_pr: 121.15008078775733
# Objective value at iteration #243 is - 83.5084
# Primal iterate: [-5.04468596  0.75500511  2.44923915]
# inf_pr: 121.02379983964757
# Objective value at iteration #244 is - 84.3873
# Primal iterate: [-5.04197787  0.64147071  2.45037196]
# inf_pr: 116.91151379629943
# Objective value at iteration #245 is - 84.8995
# Primal iterate: [-5.03988971  0.56473494  2.45124545]
# inf_pr: 114.40649652188583
# Objective value at iteration #246 is - 88.3702
# Primal iterate: [-5.03154523  0.1795362   2.45473621]
# inf_pr: 102.31527146669345
# Objective value at iteration #247 is - 88.7283
# Primal iterate: [-5.03035917  0.13310342  2.45523238]
# inf_pr: 100.96777624703364
# Objective value at iteration #248 is - 88.7716
# Primal iterate: [-5.03022211  0.12765506  2.45528972]
# inf_pr: 100.814567398239
# Objective value at iteration #249 is - 101.159
# Primal iterate: [-4.99194761 -1.3946207   2.47130136]
# inf_pr: 58.00043326114226
# Objective value at iteration #249 is - 101.159
# Primal iterate: [-4.99194761 -1.3946207   2.47130136]
# inf_pr: 58.00043326114226
# Objective value at iteration #250 is - 58.7066
# Primal iterate: [-15.90378391  -1.92179348   1.06763359]
# inf_pr: 47.608116612894655
# Objective value at iteration #251 is - 58.5961
# Primal iterate: [-15.93094828  -1.92434291   1.06397663]
# inf_pr: 47.557267202737805
# Objective value at iteration #252 is - 58.5961
# Primal iterate: [-15.93094828  -1.92434291   1.06397663]
# inf_pr: 47.557267202737805
# Objective value at iteration #253 is - 62.4611
# Primal iterate: [-15.86835514  -1.96170813   1.06941256]
# inf_pr: 23.982010490075716
# Objective value at iteration #253 is - 62.4611
# Primal iterate: [-15.86835514  -1.96170813   1.06941256]
# inf_pr: 23.982010490075716
# Objective value at iteration #254 is - 62.4611
# Primal iterate: [-15.86835514  -1.96170813   1.06941256]
# inf_pr: 23.982010490075716
# Objective value at iteration #255 is - 69.6034
# Primal iterate: [-15.79933293  -2.04010685   1.07546855]
# inf_pr: 21.65007501926366
# Objective value at iteration #256 is - 71.6969
# Primal iterate: [-15.69603034  -2.03622128   1.08457984]
# inf_pr: 21.554561675986253
# Objective value at iteration #256 is - 71.6969
# Primal iterate: [-15.69603034  -2.03622128   1.08457984]
# inf_pr: 21.554561675986253
# Objective value at iteration #257 is - 71.6115
# Primal iterate: [-15.71316533  -2.03907459   1.08247287]
# inf_pr: 21.50023628141
# Objective value at iteration #258 is - 71.6115
# Primal iterate: [-15.71316533  -2.03907459   1.08247287]
# inf_pr: 21.50023628141
# Objective value at iteration #259 is - 78.935
# Primal iterate: [-15.65420111  -2.11438434   1.08781939]
# inf_pr: 19.263136063131522
# Objective value at iteration #260 is - 83.2626
# Primal iterate: [-15.43088967  -2.09086937   1.10819053]
# inf_pr: 20.06132219972298
# Objective value at iteration #261 is - 315.712
# Primal iterate: [-13.02151166  -3.58016233   1.34428961]
# inf_pr: 306.4266162925917
# Objective value at iteration #262 is - 319.339
# Primal iterate: [-12.93980279  -3.54666324   1.35580459]
# inf_pr: 307.29889108488453
# Objective value at iteration #263 is - 462.877
# Primal iterate: [-9.74594603 -2.26305713  1.8078425 ]
# inf_pr: 340.76281313269135
# Objective value at iteration #264 is - 469.625
# Primal iterate: [-9.63646954 -2.26277048  1.82577868]
# inf_pr: 340.64193833862635
# Objective value at iteration #265 is - 469.625
# Primal iterate: [-9.63646954 -2.26277048  1.82577868]
# inf_pr: 340.64193833862635
# Objective value at iteration #266 is - 476.24
# Primal iterate: [-9.51678615 -2.28316902  1.85180894]
# inf_pr: 333.8466915637561
# Objective value at iteration #267 is - 780.998
# Primal iterate: [-4.24434271 -3.25879747  2.98556051]
# inf_pr: 43.19793250615925
# Objective value at iteration #268 is - 1000.11
# Primal iterate: [-4.36828744 -4.8277805   2.89954936]
# inf_pr: 171.69767800881533
# Objective value at iteration #269 is - 972.905
# Primal iterate: [-6.19364952 -5.86564667  2.24178611]
# inf_pr: 114.04667812838224
# Objective value at iteration #270 is - 873.342
# Primal iterate: [-6.66465453 -5.11198866  2.20126188]
# inf_pr: 75.38473079701231
# Objective value at iteration #271 is - 821.085
# Primal iterate: [-7.12180493 -4.97720811  2.17841606]
# inf_pr: 37.52295691176973
# Objective value at iteration #272 is - 811.912
# Primal iterate: [-9.76812926 -5.85185117  1.65554809]
# inf_pr: 104.70909893410747
# Objective value at iteration #273 is - 684.549
# Primal iterate: [-9.97042224 -4.97665162  1.70011068]
# inf_pr: 74.71687943796364
# Objective value at iteration #274 is - 618.918
# Primal iterate: [-9.99350603 -4.63420708  1.71049475]
# inf_pr: 47.55541513723648
# Objective value at iteration #275 is - 575.311
# Primal iterate: [-9.99353512 -4.36344118  1.71044866]
# inf_pr: 35.16894115757556
# Objective value at iteration #276 is - 543.739
# Primal iterate: [-9.99353512 -4.15851921  1.71044866]
# inf_pr: 26.291123957152763
# Objective value at iteration #277 is - 521.037
# Primal iterate: [-9.99353512 -4.00633811  1.71044866]
# inf_pr: 19.378639692695792
# Objective value at iteration #278 is - 504.869
# Primal iterate: [-9.99353512 -3.89531821  1.71044866]
# inf_pr: 14.0586847481133
# Objective value at iteration #278 is - 504.869
# Primal iterate: [-9.99353512 -3.89531821  1.71044866]
# inf_pr: 14.0586847481133
# Objective value at iteration #279 is - 470.717
# Primal iterate: [-12.46933519  -4.27473159   1.61056549]
# inf_pr: 21.337029644693963
# Objective value at iteration #280 is - 468.486
# Primal iterate: [-12.60492393  -4.3166329    1.60469773]
# inf_pr: 22.14083859570583
# Objective value at iteration #281 is - 64.1505
# Primal iterate: [-29.82604954 -13.08260981   0.61352191]
# inf_pr: 183.15549028999828
# Objective value at iteration #282 is - 41.7721
# Primal iterate: [-2.98905311e+01 -1.18974439e+01  1.60352092e-02]
# inf_pr: 155.4709671771265
# Objective value at iteration #283 is - 40.759
# Primal iterate: [-2.98866503e+01 -1.08906286e+01  1.84820607e-02]
# inf_pr: 137.03098655891804
# Objective value at iteration #284 is - 40.738
# Primal iterate: [-2.98864042e+01 -1.08708621e+01  1.94197146e-02]
# inf_pr: 136.6595923059714
# Objective value at iteration #285 is - 40.7085
# Primal iterate: [-29.88632932 -10.86534902   0.04358494]
# inf_pr: 136.55591107206482
# Objective value at iteration #286 is - 40.6845
# Primal iterate: [-29.88632803 -10.86525453   0.06774433]
# inf_pr: 136.55413413007847
# Objective value at iteration #287 is - 40.6845
# Primal iterate: [-29.88631477 -10.86523524   0.06774444]
# inf_pr: 136.55376936289971
# Objective value at iteration #288 is - 39.1652
# Primal iterate: [-28.0335819  -10.83305455   0.06792257]
# inf_pr: 135.94524771667733
# Objective value at iteration #289 is - 35.9999
# Primal iterate: [-2.93481741e+01 -6.66169196e+00  1.05792158e-02]
# inf_pr: 112.77504717183594
# Objective value at iteration #290 is - 31.769
# Primal iterate: [-28.26811741  -3.40736408   0.05714974]
# inf_pr: 66.15061352193544
# Objective value at iteration #291 is - 30.8067
# Primal iterate: [-28.57274476  -2.18928646   0.0892913 ]
# inf_pr: 24.088786441750152
# Objective value at iteration #292 is - 30.8986
# Primal iterate: [-28.57244746  -2.26557985   0.14974493]
# inf_pr: 14.410404084261145
# Objective value at iteration #293 is - 30.9001
# Primal iterate: [-28.57233548  -2.26449309   0.15720963]
# inf_pr: 14.348118632203885
# Objective value at iteration #294 is - 30.9001
# Primal iterate: [-28.57233378  -2.26447166   0.15731866]
# inf_pr: 14.347693616119479
# Objective value at iteration #295 is - 30.9001
# Primal iterate: [-28.57233378  -2.26447166   0.15731866]
# inf_pr: 14.347693616119479
# Objective value at iteration #296 is - 31.2079
# Primal iterate: [-28.38801244  -2.26020606   0.18074366]
# inf_pr: 14.360260569195807
# Objective value at iteration #297 is - 23555.8
# Primal iterate: [-18.07459245 -26.70303348   0.33706616]
# inf_pr: 2212.4670921126676
# Objective value at iteration #298 is - 22276.4
# Primal iterate: [-17.48636582 -26.23800436   0.35243325]
# inf_pr: 2147.14544852581
# Objective value at iteration #299 is - 22263.6
# Primal iterate: [-17.4805065  -26.23343986   0.35259404]
# inf_pr: 2146.484060375389
# Objective value at iteration #300 is - 22263.2
# Primal iterate: [-17.4803132  -26.23329129   0.35259976]
# inf_pr: 2146.461589897918
# Objective value at iteration #301 is - 7628.7
# Primal iterate: [ -0.59825109 -13.25809762   0.85245136]
# inf_pr: 183.98761442649288
# Objective value at iteration #302 is - 3513.55
# Primal iterate: [-6.23820386 -9.53284303  1.38591571]
# inf_pr: 194.20955264849405
# Objective value at iteration #303 is - 2105.43
# Primal iterate: [-3.65903886 -8.31245909  2.1582598 ]
# inf_pr: 140.50339987904107
# Objective value at iteration #304 is - 2589.35
# Primal iterate: [-6.07801175 -9.40932327  1.30893762]
# inf_pr: 202.6691937873959
# Objective value at iteration #305 is - 2061.26
# Primal iterate: [-6.6900079  -7.59237312  1.35411956]
# inf_pr: 149.39378639893056
# Objective value at iteration #306 is - 1756.25
# Primal iterate: [-6.7437348  -6.79706351  1.3784504 ]
# inf_pr: 107.87426614626521
# Objective value at iteration #307 is - 1565
# Primal iterate: [-6.74396724 -6.14860434  1.37822328]
# inf_pr: 82.3481014209687
# Objective value at iteration #308 is - 1427.65
# Primal iterate: [-6.74396724 -5.64612225  1.37822326]
# inf_pr: 62.2886930483935
# Objective value at iteration #309 is - 1330.39
# Primal iterate: [-6.74396724 -5.2691618   1.37822326]
# inf_pr: 45.97991133268387
# Objective value at iteration #310 is - 1262.69
# Primal iterate: [-6.74396724 -4.99507317  1.37822326]
# inf_pr: 33.02355527000788
# Objective value at iteration #311 is - 1216.35
# Primal iterate: [-6.74396724 -4.80143671  1.37822326]
# inf_pr: 23.123457866652302
# Objective value at iteration #312 is - 1320.11
# Primal iterate: [-10.02953675  -5.64442701   0.93629772]
# inf_pr: 99.83970863801699
# Objective value at iteration #313 is - 1099.38
# Primal iterate: [-10.86369979  -4.86210027   0.94778431]
# inf_pr: 70.90649821245349
# Objective value at iteration #314 is - 993.827
# Primal iterate: [-11.03304741  -4.5560627    0.95303116]
# inf_pr: 42.1682985162644
# Objective value at iteration #315 is - 930.107
# Primal iterate: [-11.03442508  -4.32140148   0.9530154 ]
# inf_pr: 30.088263433224874
# Objective value at iteration #316 is - 885.266
# Primal iterate: [-11.0344251   -4.14936665   0.9530154 ]
# inf_pr: 21.82687776115378
# Objective value at iteration #317 is - 853.916
# Primal iterate: [-11.0344251   -4.02570288   0.9530154 ]
# inf_pr: 15.59872601432442
# Objective value at iteration #318 is - 832.226
# Primal iterate: [-11.0344251   -3.93842084   0.9530154 ]
# inf_pr: 10.96437838937041
# Objective value at iteration #318 is - 832.226
# Primal iterate: [-11.0344251   -3.93842084   0.9530154 ]
# inf_pr: 10.96437838937041
# Objective value at iteration #319 is - 811.242
# Primal iterate: [-11.36973342  -4.74470095   0.92727699]
# inf_pr: 26.294749133652395
# Objective value at iteration #320 is - 811.086
# Primal iterate: [-11.37207729  -4.75080514   0.9270866 ]
# inf_pr: 26.410848791634365
# Objective value at iteration #321 is - 811.047
# Primal iterate: [-11.37268513  -4.75233082   0.92703858]
# inf_pr: 26.43992692104421
# Objective value at iteration #322 is - 811.037
# Primal iterate: [-11.37284754  -4.75271221   0.92702639]
# inf_pr: 26.44727803132941
# Objective value at iteration #323 is - 811.029
# Primal iterate: [-11.37294177  -4.75290291   0.92702142]
# inf_pr: 26.451188608476265
# Objective value at iteration #324 is - 54.3249
# Primal iterate: [-24.7959225  -29.74752933   0.31940508]
# inf_pr: 541.210558348127
# Objective value at iteration #325 is - 48.0163
# Primal iterate: [-19.45107909 -29.02525121   0.46465225]
# inf_pr: 497.6582230836234
# Objective value at iteration #326 is - 47.4596
# Primal iterate: [-19.41712623 -28.50310509   0.46526023]
# inf_pr: 483.2724281390736
# Objective value at iteration #327 is - 21.9616
# Primal iterate: [-18.46641724  -3.97258875   0.48218285]
# inf_pr: 490.4243522803397
# Objective value at iteration #328 is - 20.4259
# Primal iterate: [-17.38194535  -3.53932484   0.50037662]
# inf_pr: 20.50035952462047
# Objective value at iteration #329 is - 16.1213
# Primal iterate: [-13.81487405  -2.81074788   0.50938419]
# inf_pr: 29.46707471691188
# Objective value at iteration #330 is - 13.821
# Primal iterate: [-11.06550641  -1.51792888   0.50993489]
# inf_pr: 54.75850610421909
# Objective value at iteration #331 is - 13.821
# Primal iterate: [-11.06550641  -1.51792888   0.50993489]
# inf_pr: 54.75850610421909
# Objective value at iteration #332 is - 15.6638
# Primal iterate: [-11.05392985  -1.8977311    0.51444255]
# inf_pr: 49.250197703448315
# Objective value at iteration #332 is - 15.6638
# Primal iterate: [-11.05392985  -1.8977311    0.51444255]
# inf_pr: 49.250197703448315
# Objective value at iteration #333 is - 109.795
# Primal iterate: [ 8.8989067  -2.79202019  0.57975178]
# inf_pr: 30.45725737623539
# Objective value at iteration #334 is - 8.74993
# Primal iterate: [-2.1437832  -3.27600195  0.01569751]
# inf_pr: 22.59088166792452
# Objective value at iteration #335 is - 9.45738
# Primal iterate: [-2.26158186 -3.18693047  0.01005697]
# inf_pr: 24.39110279386957
# Objective value at iteration #336 is - 13.9158
# Primal iterate: [-2.28164723 -2.90413341  0.02374561]
# inf_pr: 27.245160140674315
# Objective value at iteration #337 is - 13.8979
# Primal iterate: [-2.30935135 -2.87797418  0.02373303]
# inf_pr: 27.717473075812812
# Objective value at iteration #338 is - 13.8979
# Primal iterate: [-2.30935135 -2.87797418  0.02373303]
# inf_pr: 27.717473075812812
# Objective value at iteration #339 is - 15.7221
# Primal iterate: [-2.30914274 -3.46670012  0.02385247]
# inf_pr: 15.88912012717271
# Objective value at iteration #340 is - 7.15839
# Primal iterate: [-2.22292754 -2.14613865  5.16680827]
# inf_pr: 40.747498482146995
# Objective value at iteration #341 is - 7.60739
# Primal iterate: [-2.21547546 -2.10736486  4.62997003]
# inf_pr: 41.23261088600088
# Objective value at iteration #342 is - 7.63418
# Primal iterate: [-2.21540032 -2.12152946  4.62533323]
# inf_pr: 40.941368158012295
# Objective value at iteration #343 is - 7.64728
# Primal iterate: [-2.21536437 -2.12876606  4.62313885]
# inf_pr: 40.79295766661503
# Objective value at iteration #344 is - 7.64781
# Primal iterate: [-2.21536263 -2.12902061  4.623033  ]
# inf_pr: 40.78769395829415
# Objective value at iteration #345 is - 7.75616
# Primal iterate: [-2.21500692 -2.18092183  4.6014381 ]
# inf_pr: 39.71445906197586
# Objective value at iteration #346 is - 7.78824
# Primal iterate: [-2.21491558 -2.19826484  4.59589574]
# inf_pr: 39.35844426396862
# Objective value at iteration #347 is - 7.80978
# Primal iterate: [-2.21483972 -2.20807016  4.59134104]
# inf_pr: 39.15508188946002
# Objective value at iteration #348 is - 7.81799
# Primal iterate: [-2.21481484 -2.21237549  4.589848  ]
# inf_pr: 39.06656357896285
# Objective value at iteration #349 is - 7.818
# Primal iterate: [-2.21481477 -2.21238288  4.58984394]
# inf_pr: 39.0664095398215
# Objective value at iteration #350 is - 7.9022
# Primal iterate: [-2.21447946 -2.24792996  4.57031266]
# inf_pr: 38.32564745057213
# Objective value at iteration #351 is - 7.93923
# Primal iterate: [-2.2143549  -2.26656605  4.56305945]
# inf_pr: 37.94169491812174
# Objective value at iteration #352 is - 7.95022
# Primal iterate: [-2.21431166 -2.27128757  4.56057111]
# inf_pr: 37.843452733628055
# Objective value at iteration #353 is - 7.9546
# Primal iterate: [-2.21429705 -2.27352224  4.55972989]
# inf_pr: 37.79745224776871
# Objective value at iteration #354 is - 7.9546
# Primal iterate: [-2.21429705 -2.27352224  4.55972989]
# inf_pr: 37.79745224776871
# Objective value at iteration #355 is - 9.55511
# Primal iterate: [-2.20823062 -2.9372897   4.21291763]
# inf_pr: 37.21007888371143
# Objective value at iteration #356 is - 9.72982
# Primal iterate: [-2.207707   -3.02476468  4.18371873]
# inf_pr: 37.5037628243636
# Objective value at iteration #357 is - 9.74634
# Primal iterate: [-2.20764986 -3.03178064  4.18057123]
# inf_pr: 37.53368729213886
# Objective value at iteration #358 is - 9.75562
# Primal iterate: [-2.20762161 -3.03633004  4.17902051]
# inf_pr: 37.54872693535289
# ...
# inf_pr: 199.30346185150532
# Objective value at iteration #2338 is - 379.201
# Primal iterate: [-4.81366406 -1.2629798   3.27031643]
# inf_pr: 199.22154135604063
# Objective value at iteration #2339 is - 384.924
# Primal iterate: [-4.68668998 -1.35370661  3.27382659]
# inf_pr: 197.59001642734742
# Objective value at iteration #2340 is - 385.056
# Primal iterate: [-4.68377864 -1.3558596   3.27390706]
# inf_pr: 197.54879549385328
# Objective value at iteration #2341 is - 387.456
# Primal iterate: [-4.63122351 -1.39476269  3.27535967]
# inf_pr: 196.80295705776945
# Objective value at iteration #2342 is - 387.629
# Primal iterate: [-4.6274566  -1.39759101  3.27546378]
# inf_pr: 196.74739639451082
# Objective value at iteration #2343 is - 394.086
# Primal iterate: [-4.48727212 -1.50296402  3.27933807]
# inf_pr: 194.67386426925066
# Objective value at iteration #2344 is - 394.159
# Primal iterate: [-4.48572773 -1.50417028  3.27938074]
# inf_pr: 194.64860856207991
# Objective value at iteration #2345 is - 399.201
# Primal iterate: [-4.37800273 -1.58836476  3.28235731]
# inf_pr: 192.88456578658042
# Objective value at iteration #2346 is - 399.272
# Primal iterate: [-4.37651092 -1.58956573  3.28239853]
# inf_pr: 192.8582602834926
# Objective value at iteration #2347 is - 400.185
# Primal iterate: [-4.35722284 -1.60510113  3.2829314 ]
# inf_pr: 192.51776315511518
# Objective value at iteration #2348 is - 400.283
# Primal iterate: [-4.35516104 -1.60677061  3.28298837]
# inf_pr: 192.48089224346074
# Objective value at iteration #2349 is - 414.932
# Primal iterate: [-4.0487282  -1.85504156  3.29145399]
# inf_pr: 186.99323557574218
# Objective value at iteration #2350 is - 415.073
# Primal iterate: [-4.04586684 -1.85757531  3.29153302]
# inf_pr: 186.93036857978362
# Objective value at iteration #2351 is - 513.657
# Primal iterate: [-2.14034362 -3.54675908  3.34414878]
# inf_pr: 144.9591581173934
# Objective value at iteration #2352 is - 513.385
# Primal iterate: [-2.14677708 -3.58292901  3.33457946]
# inf_pr: 142.189515135679
# Objective value at iteration #2353 is - 513.42
# Primal iterate: [-2.1472476  -3.59265282  3.33354428]
# inf_pr: 141.83643874949823
# Objective value at iteration #2354 is - 519.107
# Primal iterate: [-2.2183506  -5.05723996  3.17731713]
# inf_pr: 88.62213047838792
# Objective value at iteration #2355 is - 519.131
# Primal iterate: [-2.2188493  -5.06513184  3.17630042]
# inf_pr: 88.3192662023264
# Objective value at iteration #2356 is - 522.146
# Primal iterate: [-2.2899034  -6.02275356  3.04155873]
# inf_pr: 74.18655704954044
# Objective value at iteration #2357 is - 522.157
# Primal iterate: [-2.29051951 -6.02912109  3.0404621 ]
# inf_pr: 74.14279705147172
# Objective value at iteration #2358 is - 531.845
# Primal iterate: [-2.63813285 -8.93483656  2.47907588]
# inf_pr: 83.88644174632933
# Objective value at iteration #2359 is - 497.994
# Primal iterate: [-2.79357206 -7.1413595   2.33215758]
# inf_pr: 54.389557602058716
# Objective value at iteration #2360 is - 472.946
# Primal iterate: [-4.74813617 -9.52866885  1.45062425]
# inf_pr: 172.097994448837
# Objective value at iteration #2361 is - 364.203
# Primal iterate: [-5.57270186 -4.87233499  1.50424243]
# inf_pr: 99.49642908046543
# Objective value at iteration #2362 is - 339.246
# Primal iterate: [-5.621801   -4.32772607  1.53345712]
# inf_pr: 16.675136008555306
# Objective value at iteration #2363 is - 306.79
# Primal iterate: [-8.74100844 -6.20121895  0.97494246]
# inf_pr: 93.13550975780333
# Objective value at iteration #2364 is - 243.775
# Primal iterate: [-9.40630262 -3.65869165  1.01550778]
# inf_pr: 54.233302388540295
# Objective value at iteration #2365 is - 225.651
# Primal iterate: [-9.50623605 -3.20758841  1.03360763]
# inf_pr: 11.834648541361371
# Objective value at iteration #2366 is - 224.36
# Primal iterate: [-9.50871512 -3.16918494  1.03481129]
# inf_pr: 7.261217806711027
# Objective value at iteration #2367 is - 223.984
# Primal iterate: [-9.54097028 -3.1798356   1.0317657 ]
# inf_pr: 7.6148519025991845
# Objective value at iteration #2368 is - 223.979
# Primal iterate: [-9.54130174 -3.17994749  1.0317432 ]
# inf_pr: 7.617414612359809
# Objective value at iteration #2369 is - 222.078
# Primal iterate: [-9.68142203 -3.22722577  1.02223065]
# inf_pr: 8.700520032090225
# Objective value at iteration #2370 is - 221.185
# Primal iterate: [-9.72796377 -3.23241855  1.01906002]
# inf_pr: 8.815908461650896
# Objective value at iteration #2371 is - 221.175
# Primal iterate: [-9.72853974 -3.23246306  1.01901814]
# inf_pr: 8.817289055968434
# Objective value at iteration #2372 is - 221.175
# Primal iterate: [-9.72853974 -3.23246306  1.01901814]
# inf_pr: 8.817289055968434
# Objective value at iteration #2373 is - 205.262
# Primal iterate: [-10.63846179  -3.3038942    0.95277653]
# inf_pr: 11.041008629671804
# Objective value at iteration #2374 is - 205.204
# Primal iterate: [-10.64300631  -3.30495645   0.95244112]
# inf_pr: 11.069973778333999
# Objective value at iteration #2375 is - 205.149
# Primal iterate: [-10.64762236  -3.3058783    0.95208282]
# inf_pr: 11.099283442635514
# Objective value at iteration #2376 is - 204.784
# Primal iterate: [-10.66886772  -3.30591571   0.95043354]
# inf_pr: 11.128857620904377
# Objective value at iteration #2377 is - 204.784
# Primal iterate: [-10.66886772  -3.30591571   0.95043354]
# inf_pr: 11.128857620904377
# Objective value at iteration #2378 is - 195.529
# Primal iterate: [-11.44797172  -3.45565382   0.88954489]
# inf_pr: 16.101955057403252
# Objective value at iteration #2379 is - 174.121
# Primal iterate: [-12.56550207  -3.34575707   0.80172608]
# inf_pr: 14.912054436302832
# Objective value at iteration #2380 is - 167.966
# Primal iterate: [-12.95513944  -3.35248932   0.77104617]
# inf_pr: 15.78288339388217
# Objective value at iteration #2381 is - 151.712
# Primal iterate: [-13.81819879  -3.25637237   0.70308442]
# inf_pr: 14.97441320984903
# Objective value at iteration #2382 is - 138.25
# Primal iterate: [-13.82684737  -2.71460683   0.7023922 ]
# inf_pr: 17.603608474981318
# Objective value at iteration #2383 is - 83.8981
# Primal iterate: [-17.99987654  -2.93595319   0.43241021]
# inf_pr: 14.931182119721472
# Objective value at iteration #2384 is - 80.6997
# Primal iterate: [-17.85939581  -2.38597232   0.45453496]
# inf_pr: 25.818497827091072
# Objective value at iteration #2385 is - 80.6505
# Primal iterate: [-17.85151813  -2.3860895    0.4556959 ]
# inf_pr: 25.81369979857775
# Objective value at iteration #2386 is - 80.6497
# Primal iterate: [-17.85073639  -2.38620989   0.45580232]
# inf_pr: 25.811079768742136
# Objective value at iteration #2387 is - 80.6494
# Primal iterate: [-17.85035267  -2.3862688    0.45585405]
# inf_pr: 25.809797238516463
# Objective value at iteration #2388 is - 80.6494
# Primal iterate: [-17.85034077  -2.38627063   0.45585565]
# inf_pr: 25.80975741996757
# Objective value at iteration #2389 is - 80.6494
# Primal iterate: [-17.85033482  -2.38627154   0.45585645]
# inf_pr: 25.809737514961974
# Objective value at iteration #2390 is - 80.6111
# Primal iterate: [-17.80160907  -2.39376141   0.46242752]
# inf_pr: 25.646692424963064
# Objective value at iteration #2391 is - 80.6111
# Primal iterate: [-17.80111012  -2.39385342   0.46249481]
# inf_pr: 25.644707013457406
# Objective value at iteration #2392 is - 80.6111
# Primal iterate: [-17.80102969  -2.39386827   0.46250565]
# inf_pr: 25.644386485518616
# Objective value at iteration #2393 is - 80.6243
# Primal iterate: [-17.68187009  -2.41588494   0.47857529]
# inf_pr: 25.169359366764503
# Objective value at iteration #2394 is - 80.8569
# Primal iterate: [-17.68187009  -2.4267284    0.47857529]
# inf_pr: 24.9457604089296
# Objective value at iteration #2395 is - 54.2842
# Primal iterate: [-21.1121752   -2.88063707   0.2976668 ]
# inf_pr: 16.58552041338488
# Objective value at iteration #2396 is - 52.6298
# Primal iterate: [-20.88237739  -2.57642916   0.31252398]
# inf_pr: 22.659788066794196
# Objective value at iteration #2397 is - 51.5135
# Primal iterate: [-20.69615278  -2.41943055   0.32718546]
# inf_pr: 25.819959888048135
# Objective value at iteration #2398 is - 50.8951
# Primal iterate: [-20.68315226  -2.38350188   0.32855227]
# inf_pr: 26.56179273075492
# Objective value at iteration #2399 is - 50.5931
# Primal iterate: [-20.68224433  -2.36623205   0.32868097]
# inf_pr: 26.9184084092112
# Objective value at iteration #2400 is - 50.4333
# Primal iterate: [-20.68224439  -2.3569977    0.32868094]
# inf_pr: 27.109072780692145
# Objective value at iteration #2401 is - 50.3481
# Primal iterate: [-20.68224439  -2.35206449   0.32868094]
# inf_pr: 27.210930282659064
# Objective value at iteration #2402 is - 50.3027
# Primal iterate: [-20.68224439  -2.34942908   0.32868094]
# inf_pr: 27.265344491255206
# Objective value at iteration #2403 is - 38.8446
# Primal iterate: [-23.56403552  -2.44860612   0.19131324]
# inf_pr: 25.7771444444716
# Objective value at iteration #2404 is - 38.1944
# Primal iterate: [-23.57900974  -2.30768924   0.19188804]
# inf_pr: 28.57266844791796
# Objective value at iteration #2405 is - 38.108
# Primal iterate: [-23.58608665  -2.30282357   0.19219964]
# inf_pr: 28.672123258391817
# Objective value at iteration #2406 is - 38.1043
# Primal iterate: [-23.58654117  -2.30271251   0.19222202]
# inf_pr: 28.674387895477597
# Objective value at iteration #2407 is - 38.1034
# Primal iterate: [-23.58665133  -2.30268502   0.19222743]
# inf_pr: 28.674948518871805
# Objective value at iteration #2408 is - 38.103
# Primal iterate: [-23.58670599  -2.30267132   0.19223012]
# inf_pr: 28.67522809828699
# Objective value at iteration #2409 is - 38.1029
# Primal iterate: [-23.58671959  -2.30266789   0.19223078]
# inf_pr: 28.675297902164285
# Objective value at iteration #2410 is - 37.9904
# Primal iterate: [-23.60064232  -2.29916488   0.19291479]
# inf_pr: 28.74675367479052
# Objective value at iteration #2411 is - 37.9705
# Primal iterate: [-23.60064232  -2.29685796   0.19291479]
# inf_pr: 28.79443011502376
# Objective value at iteration #2412 is - 37.9597
# Primal iterate: [-23.60064232  -2.2956039    0.19291479]
# inf_pr: 28.820347161756786
# Objective value at iteration #2413 is - 37.9538
# Primal iterate: [-23.60064232  -2.2949222    0.19291479]
# inf_pr: 28.834435644373173
# Objective value at iteration #2414 is - 37.9506
# Primal iterate: [-23.60064232  -2.29455163   0.19291479]
# inf_pr: 28.84209412659851
# Objective value at iteration #2415 is - 37.9489
# Primal iterate: [-23.60064232  -2.29435019   0.19291479]
# inf_pr: 28.84625726719177
# Objective value at iteration #2416 is - 38.6295
# Primal iterate: [-25.3526824   -2.33066768   0.11191069]
# inf_pr: 28.29023309583327
# Objective value at iteration #2417 is - 38.4603
# Primal iterate: [-25.43267559  -2.29008734   0.1083901 ]
# inf_pr: 29.103077767064434
# Objective value at iteration #2418 is - 38.7035
# Primal iterate: [-25.5014336   -2.28657241   0.10328366]
# inf_pr: 29.17575110472536
# Objective value at iteration #2419 is - 38.826
# Primal iterate: [-25.5235939   -2.28530095   0.10124753]
# inf_pr: 29.202041811387073
# Objective value at iteration #2420 is - 38.85
# Primal iterate: [-25.52776993  -2.28501702   0.10085522]
# inf_pr: 29.207912745357707
# Objective value at iteration #2421 is - 38.8613
# Primal iterate: [-25.52972758  -2.28487888   0.1006711 ]
# inf_pr: 29.210769066209117
# Objective value at iteration #2422 is - 38.8614
# Primal iterate: [-25.52975721  -2.28487675   0.10066831]
# inf_pr: 29.2108130938394
# Objective value at iteration #2423 is - 39.2315
# Primal iterate: [-25.59041477  -2.28051687   0.0949631 ]
# inf_pr: 29.300962379664725
# Objective value at iteration #2424 is - 39.203
# Primal iterate: [-25.59041477  -2.278041     0.0949631 ]
# inf_pr: 29.352150441268535
# Objective value at iteration #2425 is - 39.1874
# Primal iterate: [-25.59041477  -2.27668603   0.0949631 ]
# inf_pr: 29.380164076119478
# Objective value at iteration #2426 is - 39.1788
# Primal iterate: [-25.59041477  -2.2759445    0.0949631 ]
# inf_pr: 29.395495047758235
# Objective value at iteration #2427 is - 39.1741
# Primal iterate: [-25.59041477  -2.27553868   0.0949631 ]
# inf_pr: 29.40388520022121
# Objective value at iteration #2428 is - 39.1716
# Primal iterate: [-25.59041477  -2.27531659   0.0949631 ]
# inf_pr: 29.408476863169803
# Objective value at iteration #2429 is - 39.1702
# Primal iterate: [-25.59041477  -2.27519505   0.0949631 ]
# inf_pr: 29.410989733834022
# Objective value at iteration #2430 is - 39.1694
# Primal iterate: [-25.59041477  -2.27512853   0.0949631 ]
# inf_pr: 29.412364947768666
# Objective value at iteration #2431 is - 39.169
# Primal iterate: [-25.59041477  -2.27509213   0.0949631 ]
# inf_pr: 29.413117558468358
# Objective value at iteration #2432 is - 39.1688
# Primal iterate: [-25.59041477  -2.27507221   0.0949631 ]
# inf_pr: 29.413529438284396
# Objective value at iteration #2433 is - 39.1686
# Primal iterate: [-25.59041477  -2.27506131   0.0949631 ]
# inf_pr: 29.413754846961805
# Objective value at iteration #2434 is - 39.1686
# Primal iterate: [-25.59041477  -2.27505534   0.0949631 ]
# inf_pr: 29.413878205936427
# Objective value at iteration #2435 is - 41.7351
# Primal iterate: [-26.16866009  -2.28155903   0.06159901]
# inf_pr: 29.313696375962294
# Objective value at iteration #2436 is - 41.9198
# Primal iterate: [-26.1939967   -2.27576463   0.05983439]
# inf_pr: 29.431357814411154
# Objective value at iteration #2437 is - 43.0319
# Primal iterate: [-26.20403223  -2.27479964   0.05493522]
# inf_pr: 29.451316101546176
# Objective value at iteration #2438 is - 43.9188
# Primal iterate: [-26.20910206  -2.27405006   0.05161929]
# inf_pr: 29.46681755206651
# Objective value at iteration #2439 is - 43.9821
# Primal iterate: [-26.20941894  -2.27397737   0.05139778]
# inf_pr: 29.46832069805272
# Objective value at iteration #2440 is - 43.9858
# Primal iterate: [-26.20943751  -2.27397296   0.05138474]
# inf_pr: 29.468412003603863
# Objective value at iteration #2441 is - 43.9867
# Primal iterate: [-26.20944213  -2.27397185   0.05138149]
# inf_pr: 29.468434789875687
# Objective value at iteration #2442 is - 45.0099
# Primal iterate: [-26.21417216  -2.27284398   0.04805782]
# inf_pr: 29.491757681735915
# Objective value at iteration #2443 is - 44.998
# Primal iterate: [-26.21417216  -2.27222341   0.04805781]
# inf_pr: 29.50458895921246
# Objective value at iteration #2444 is - 44.9914
# Primal iterate: [-26.21417216  -2.27188335   0.04805781]
# inf_pr: 29.5116201559862
# Objective value at iteration #2445 is - 44.9878
# Primal iterate: [-26.21417216  -2.271697     0.04805781]
# inf_pr: 29.515473063621364
# Objective value at iteration #2446 is - 44.9859
# Primal iterate: [-26.21417216  -2.27159489   0.04805781]
# inf_pr: 29.51758435387486
# Objective value at iteration #2447 is - 44.9848
# Primal iterate: [-26.21417216  -2.27153894   0.04805781]
# inf_pr: 29.518741284419864
# Objective value at iteration #2448 is - 44.9842
# Primal iterate: [-26.21417216  -2.27150828   0.04805781]
# inf_pr: 29.519375251390056
# Objective value at iteration #2449 is - 44.9839
# Primal iterate: [-26.21417216  -2.27149147   0.04805781]
# inf_pr: 29.519722648319735
# Objective value at iteration #2450 is - 44.9837
# Primal iterate: [-26.21417216  -2.27148227   0.04805781]
# inf_pr: 29.519913012538076
# Objective value at iteration #2451 is - 44.9836
# Primal iterate: [-26.21417216  -2.27147722   0.04805781]
# inf_pr: 29.520017327034047
# Objective value at iteration #2452 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147446   0.04805781]
# inf_pr: 29.52007448858553
# Objective value at iteration #2453 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147294   0.04805781]
# inf_pr: 29.520105811585623
# Objective value at iteration #2454 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147211   0.04805781]
# inf_pr: 29.520122975751228
# Objective value at iteration #2455 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147166   0.04805781]
# inf_pr: 29.52013238125453
# Objective value at iteration #2456 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147141   0.04805781]
# inf_pr: 29.520137535218552
# Objective value at iteration #2457 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147127   0.04805781]
# inf_pr: 29.520140359452895
# Objective value at iteration #2458 is - 44.9835
# Primal iterate: [-26.21417216  -2.2714712    0.04805781]
# inf_pr: 29.52014190705771
# Objective value at iteration #2459 is - 44.9835
# Primal iterate: [-26.21417216  -2.27147116   0.04805781]
# inf_pr: 29.52014275510373

# %%
info
# Out:
# {'x': array([-26.21417216,  -2.27147116,   0.04805781,  30.3109987 ,
#          30.75906908,  23.14730764,  22.70173969,  22.53311431,
#          22.53311431,  22.53311431,  22.53311431,  22.53311431,
#          22.53311431,  22.53311431,  10.70820575,  22.53311431,
#          11.60445159,  22.53311431,  22.53311431,  22.53311431,
#          22.53311431,  13.29886941,  22.53311431]),
#  'g': array([ 5.13966116e-04, -3.52933515e+01, -6.43122007e+01, -4.82981389e+01,
#         -3.07342738e+01, -5.82283252e+01, -4.18805782e+01, -4.56693575e+01,
#         -4.78765244e+01, -5.11666836e+01, -3.71242054e+01,  1.04667049e+01,
#         -6.03433738e+01, -1.10916305e+00, -4.28249960e+01, -3.67484384e+01,
#         -6.15443865e+01, -4.50686683e+01,  2.95301428e+01, -6.11693016e+01]),
#  'obj_val': 44.983468275286974,
#  'mult_g': array([1.10214527e-05, 2.96008206e-09, 1.62417411e-09, 2.16293185e-09,
#         3.39918864e-09, 1.79395304e-09, 2.49444937e-09, 2.28746568e-09,
#         2.18198448e-09, 2.04163699e-09, 2.81408748e-09, 1.00000000e+03,
#         1.73104833e-09, 9.34059506e-08, 2.43942916e-09, 2.84286548e-09,
#         1.69725272e-09, 2.31796091e-09, 1.00000000e+03, 1.70766484e-09]),
#  'mult_x_L': array([2.76129118e-08, 3.77004269e-09, 2.74681345e-06, 3.44997667e-09,
#         3.39970417e-09, 4.51814620e-09, 4.60686311e-09, 4.64135364e-09,
#         4.64135364e-09, 4.64135364e-09, 4.64135364e-09, 4.64135364e-09,
#         4.64135364e-09, 4.64135364e-09, 9.77152065e-09, 4.64135364e-09,
#         9.01618655e-09, 4.64135364e-09, 4.64135364e-09, 4.64135364e-09,
#         4.64135364e-09, 7.86656376e-09, 4.64135364e-09]),
#  'mult_x_U': array([1.85963315e-09, 3.23932358e-09, 1.04588000e-09, 1.07805428e-10,
#         1.07855265e-10, 1.07014843e-10, 1.06966053e-10, 1.06947600e-10,
#         1.06947600e-10, 1.06947600e-10, 1.06947600e-10, 1.06947600e-10,
#         1.06947600e-10, 1.06947600e-10, 1.05669266e-10, 1.06947600e-10,
#         1.05765083e-10, 1.06947600e-10, 1.06947600e-10, 1.06947600e-10,
#         1.06947600e-10, 1.05946709e-10, 1.06947600e-10]),
#  'status': 2,
#  'status_msg': b'Algorithm converged to a point of local infeasibility. Problem may be infeasible.'}
